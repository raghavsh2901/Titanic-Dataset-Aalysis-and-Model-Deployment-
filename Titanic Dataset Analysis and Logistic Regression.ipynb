# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
titanic=pd.read_csv(r'C:\Users\user\Desktop\EXACKT\Dataset\titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
sns.pairplot(titanic)

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
titanic['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
titanic['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic['Parch'].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
titanic['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
sum((titanic['SibSp']==0)&(titanic['Parch']==0))
# Out:
# 537

# %%
plt.figure(figsize=(13,8))
sns.heatmap(pd.isnull(titanic),cbar=False,cmap='viridis')

# %%
df1=titanic.drop(['PassengerId','Name','Ticket','Cabin'],axis=1)

# %%
df1
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  22.0      1      0    7.2500        S
# 1           1       1  female  38.0      1      0   71.2833        C
# 2           1       3  female  26.0      0      0    7.9250        S
# 3           1       1  female  35.0      1      0   53.1000        S
# 4           0       3    male  35.0      0      0    8.0500        S
# 5           0       3    male   NaN      0      0    8.4583        Q
# 6           0       1    male  54.0      0      0   51.8625        S
# 7           0       3    male   2.0      3      1   21.0750        S
# 8           1       3  female  27.0      0      2   11.1333        S
# 9           1       2  female  14.0      1      0   30.0708        C
# 10          1       3  female   4.0      1      1   16.7000        S
# 11          1       1  female  58.0      0      0   26.5500        S
# 12          0       3    male  20.0      0      0    8.0500        S
# ...

# %%
df1.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
sns.countplot(x='Survived',data=df1)

# %%
sns.countplot(x='Survived',data=df1,hue='Sex')

# %%
sns.countplot(x='Survived',data=df1,hue='Pclass')

# %%
sns.countplot(x='Survived',data=df1,hue='SibSp')

# %%
sns.countplot(x='Survived',data=df1,hue='Parch')

# %%
sns.barplot(x='Sex',y='Age',data=df1,hue='Pclass')

# %%
sns.barplot(x='Survived',y='Age',data=df1,hue='Sex')

# %%
sns.barplot(x='Survived',y='Age',data=df1,hue='Pclass')

# %%
sns.pairplot(df1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Fare        891 non-null float64
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
sns.barplot(x='Survived',y='Age',data=df1,hue='SibSp')

# %%
sns.barplot(x='Survived',y='Age',data=df1,hue='Parch')

# %%
#sns.distplot(titanic['Age'])

# %%
sex1=titanic['Sex'].values
pclass1=titanic['Pclass'].values
surv1=titanic['Survived'].values


def treat_age (d):
    sx=d['Sex']
    pc=d['Pclass']
    sv=d['Survived']
    ag=d['Age']
    if pd.isnull(ag):
        for sex in sex1:
            for pclass in pclass1:
                for surv in surv1:
                    if sx==sex and pc==pclass and sv ==surv:
                        return df1['Age'][(df1['Sex']==sx) & (df1['Pclass']==pc) &(df1['Survived']==sv)].mean()
    else:
        return ag

# %%
df1['Age']=df1[['Sex','Pclass','Survived','Age']].apply(treat_age,axis=1)

# %%
sns.distplot(df1['Age'])

# %%
plt.figure(figsize=(13,8))
sns.heatmap(pd.isnull(df1),cbar=False,cmap='viridis')

# %%
df1.dropna(inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 8 columns):
# Survived    889 non-null int64
# Pclass      889 non-null int64
# Sex         889 non-null object
# Age         889 non-null float64
# SibSp       889 non-null int64
# Parch       889 non-null int64
# Fare        889 non-null float64
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 62.5+ KB

# %%
df1['male']=pd.get_dummies(df1['Sex'],drop_first=True)

# %%
emb= pd.get_dummies(df1['Embarked'])

# %%
df1=pd.concat([df1,emb],axis=1)

# %%
df1.drop(['Sex','Embarked'],axis=1,inplace=True)

# %%
plt.figure(figsize=(13,8))
sns.heatmap(pd.isnull(df1),cbar=False,cmap='viridis')

# %%
df1.head(1)
# Out:
#    Survived  Pclass   Age  SibSp  Parch  Fare  male  C  Q  S
# 0         0       3  22.0      1      0  7.25     1  0  0  1

# %%
X = df1.drop('Survived',axis=1)
y = df1['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression().fit(X_train,y_train)

# %%
pred=model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82       165
#            1       0.73      0.65      0.68       102
#
#    micro avg       0.77      0.77      0.77       267
#    macro avg       0.76      0.75      0.75       267
# weighted avg       0.77      0.77      0.77       267

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[140  25]
#  [ 36  66]]
